# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the dataset to python environment

# %%
data=pd.read_excel(r'C:\Users\nithin padmanabhan\Downloads\iris.xls')

# %% [markdown]
# ### Display the columns in the dataset

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ### Calculate the mean of each column of the dataset

# %%
data.mean()
# Out:
# C:\Users\nithin padmanabhan\AppData\Local\Temp\ipykernel_7028\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### check for the null values present in the dataset

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### perform meaningful visuaisations using dataset

# %% [markdown]
# bar graph

# %%
plt.bar(data['Classification'],data['SL'])
plt.title('Bar Graph')
plt.xlabel('Classification')
plt.ylabel('SL')
plt.show()

# %%
plt.bar(data['Classification'],data['SW'])
plt.xlabel('Classification')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
plt.bar(data['Classification'],data['PL'])
plt.xlabel('Classification')
plt.ylabel('PL')
# Out:
# Text(0, 0.5, 'PL')

# %%
plt.bar(data['Classification'],data['PW'])
plt.xlabel('Classification')
plt.ylabel('PW')
# Out:
# Text(0, 0.5, 'PW')

# %% [markdown]
# boxplot

# %%
data1=data.set_index('Classification')
sns.boxplot(data1)
plt.show()

# %% [markdown]
# scatterplot

# %%
plt.scatter(data['SL'],data['SW'])
plt.scatter(data['PL'],data['PW'])
plt.show()

# %% [markdown]
# histogram

# %%
plt.hist(data['SL'])
plt.show()

# %%
plt.hist(data['SW'])
plt.show()

# %%
plt.hist(data['PW'])
plt.show()

# %% [markdown]
# correlation

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True,cmap='PiYG')
# Out:
# C:\Users\nithin padmanabhan\AppData\Local\Temp\ipykernel_7028\3198467149.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()
# <Axes: >
